# %%
# !git clone https://github.com/nnhatdu/SemanticSegmentation-DeepLabv3.git
# Out:
# Cloning into 'tensorflow-deeplab_v3_plus'...
# remote: Enumerating objects: 140, done.
# remote: Total 140 (delta 0), reused 0 (delta 0), pack-reused 140
# Receiving objects: 100% (140/140), 2.55 MiB | 27.74 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# %cd /content/SemanticSegmentaition-DeepLabv3/src
# Out:
# [WinError 3] The system cannot find the path specified: '/content/SemanticSegmentaition-DeepLabv3/'
# c:\Users\nnhat\OneDrive - VNU-HCMUS\Sem 8\Computer Vision\project\19127120_19127550_DOAN\Source

# %%
# !wget -O - http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar > ./data/VOCtrainval_11-May-2012.tar
# !wget -O - https://www.dropbox.com/s/oeu149j8qtbs1x0/SegmentationClassAug.zip?dl=1 > ./data/SegmentationClassAug.zip
# Out:
# --2022-04-11 11:56:07--  http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/x-tar]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.86G  14.3MB/s    in 2m 16s
#
# 2022-04-11 11:58:24 (14.0 MB/s) - written to stdout [1999639040/1999639040]
#
# --2022-04-11 11:58:24--  https://www.dropbox.com/s/oeu149j8qtbs1x0/SegmentationClassAug.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/oeu149j8qtbs1x0/SegmentationClassAug.zip [following]
# ...

# %%
# !tar -xvf ./data/VOCtrainval_11-May-2012.tar -C ./data
# !mkdir ./data/SegmentationClassAug
# !unzip ./data/SegmentationClassAug.zip -d ./data
# !rm -r -f ./data/__MACOSX/
# !mv ./data/SegmentationClassAug ./data/VOCdevkit/VOC2012/
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003928.png
#   inflating: ./data/SegmentationClassAug/2010_003929.png
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003929.png
#   inflating: ./data/SegmentationClassAug/2010_003931.png
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003931.png
#   inflating: ./data/SegmentationClassAug/2010_003933.png
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003933.png
#   inflating: ./data/SegmentationClassAug/2010_003936.png
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003936.png
#   inflating: ./data/SegmentationClassAug/2010_003937.png
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003937.png
#   inflating: ./data/SegmentationClassAug/2010_003938.png
#   inflating: ./data/__MACOSX/SegmentationClassAug/._2010_003938.png
#   inflating: ./data/SegmentationClassAug/2010_003939.png
# ...

# %%
# !wget -O - http://download.tensorflow.org/models/resnet_v2_101_2017_04_14.tar.gz > ./resnet_v2_101_2017_04_14.tar.gz
# Out:
# --2022-04-11 11:58:47--  http://download.tensorflow.org/models/resnet_v2_101_2017_04_14.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.12.128, 2404:6800:4003:c11::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.12.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 499948384 (477M) [application/x-tar]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>] 476.79M  23.9MB/s    in 23s
#
# 2022-04-11 11:59:11 (20.9 MB/s) - written to stdout [499948384/499948384]

# %%
# !mkdir ./model
# !mkdir ./graph
# !mkdir ./resnet_v2_101
# !tar -xvzf resnet_v2_101_2017_04_14.tar.gz -C ./resnet_v2_101/
# Out:
# resnet_v2_101.ckpt
# train.graph
# eval.graph

# %%
# %tensorflow_version 1.4.1
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.4.1`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# !cp ./data/tfrecord/train.txt ./data/
# !cp ./data/tfrecord/test.txt ./data/
# !cp ./data/tfrecord/val.txt ./data/

# %%
# !python tfrecord.py
# Out:
# WARNING:tensorflow:From tfrecord.py:123: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From tfrecord.py:123: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From tfrecord.py:24: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:读取数据
# WARNING:tensorflow:From /content/tensorflow-deeplab_v3_plus/utils/dataset_util.py:37: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From tfrecord.py:55: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# INFO:tensorflow:On image 0 of 10582
# INFO:tensorflow:On image 500 of 10582
# INFO:tensorflow:On image 1000 of 10582
# INFO:tensorflow:On image 1500 of 10582
# INFO:tensorflow:On image 2000 of 10582
# INFO:tensorflow:On image 2500 of 10582
# ...

# %%
# !python train.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:173: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From train.py:173: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From train.py:38: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
# !python test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From test.py:19: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# ...
